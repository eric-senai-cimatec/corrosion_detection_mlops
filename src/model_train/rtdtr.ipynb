# %%
from ultralytics import RTDETR
import os
os.environ["MLFLOW_TRACKING_URI"] = "http://127.0.0.1:5000"

# %% [markdown]
# # Train model

# %%
# Load a model
version = "rtdetr-l.pt"
model = RTDETR(version)

# Train the model
model.train(
    data=r"C:\Users\eric.santoss\OneDrive - Sistema FIEB\Documentos\CORROSAO_FABRIC_MAINTENENCE\YOLODataset\dataset.yaml",
    epochs=100,
    imgsz=640,
    batch=2,
    workers=2,
    name=f"custom_yolo_model_{version.split('.')[0]}"
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.137 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.120  Python-3.11.5 torch-2.13.0+cu130 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# ...
