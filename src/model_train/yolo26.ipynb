# %%
from ultralytics import YOLO

# %% [markdown]
# # Train model

# %%
# Load a model
version = "yolo26n.pt"
model = YOLO("yolo26n.pt")
# Train the model
model.train(
    data=r"C:\Users\eric.santoss\Documents\corrosion_detection_mlops\data",
    epochs=100,
    imgsz=640,
    batch=8,
    augment=True,
    name=f"custom_yolo_model_{version.split('.')[0]}"
)
# Out:
# Ultralytics 8.4.139  Python-3.11.5 torch-2.14.0+cu130 CUDA:0 (NVIDIA GeForce RTX 3050 6GB Laptop GPU, 6144MiB)
# ...
